# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
LTS = pd.read_csv('listings.csv', delimiter = ',', header = 0)
NBH = pd.read_csv('neighbourhoods.csv', delimiter = ',', header = 0)
REW = pd.read_csv('reviews.csv', delimiter = ',', header = 0)
CAL = pd.read_csv('calendar.csv.gz', delimiter = ',', header = 0, low_memory=False)
LTS_GZ = pd.read_csv('listings.csv.gz', delimiter = ',', header = 0, low_memory=False)
REW_GZ = pd.read_csv('reviews.csv.gz', delimiter = ',', header = 0, low_memory=False)
NBH_J= pd.read_json('neighbourhoods.geojson', lines=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
####Begin Data Cleaning

# %%
LTS.drop(columns=['neighbourhood_group','last_review'],inplace=True)
NBH.drop(columns=['neighbourhood_group'],inplace=True)

# %%
LTS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9148 entries, 0 to 9147
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              9148 non-null   int64
#  1   name                            9146 non-null   object
#  2   host_id                         9148 non-null   int64
#  3   host_name                       9147 non-null   object
#  4   neighbourhood                   9148 non-null   object
#  5   latitude                        9148 non-null   float64
#  6   longitude                       9148 non-null   float64
#  7   room_type                       9148 non-null   object
#  8   price                           9148 non-null   int64
#  9   minimum_nights                  9148 non-null   int64
#  10  number_of_reviews               9148 non-null   int64
#  11  reviews_per_month               6988 non-null   float64
#  12  calculated_host_listings_count  9148 non-null   int64
#  13  availability_365                9148 non-null   int64
# dtypes: float64(3), int64(7), object(4)
# memory usage: 1000.7+ KB

# %%
CAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3339128 entries, 0 to 3339127
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 178.3+ MB

# %%
#rp=CAL.loc[CAL['listing_id']== 153545, ['price']]

# %%
#rp['price'] = rp['price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-487d1d0b1148> in <module>
# ----> 1 rp['price'] = rp['price'].astype(float)
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\miniconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\miniconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     895     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     896         # Explicit copy, or required since NumPy can't view from / to object.
# --> 897         return arr.astype(dtype, copy=True)
#     898
#     899     return arr.view(dtype)
#
# ValueError: could not convert string to float: '$49.00'

# %%
LTS_GZ.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=106)

# %%
#30+ COLUMNS DROPPED FROM LTS_GZ, FINAL SHAPE = (9148rows, 73columns)
# LTS_GZ.drop(columns=['listing_url','scrape_id', 'last_scraped', 'experiences_offered', 'host_thumbnail_url', 'host_picture_url','host_verifications','neighbourhood_group_cleansed', 'calendar_last_scraped', 'license'],inplace=True)
# LTS_GZ.drop(columns=['thumbnail_url','medium_url','picture_url','host_url','host_has_profile_pic','host_identity_verified', 'square_feet', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights','maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'cancellation_policy'],inplace=True)
# LTS_GZ.drop(columns=['xl_picture_url','bed_type','guests_included','has_availability','availability_30', 'availability_60', 'availability_60', 'jurisdiction_names', 'requires_license'],inplace=True)

# %%
LTS_GZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9148 entries, 0 to 9147
# Data columns (total 73 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9148 non-null   int64
#  1   name                                          9146 non-null   object
#  2   summary                                       8923 non-null   object
#  3   space                                         7005 non-null   object
#  4   description                                   9036 non-null   object
#  5   neighborhood_overview                         6284 non-null   object
#  6   notes                                         4209 non-null   object
#  7   transit                                       6381 non-null   object
#  8   access                                        5428 non-null   object
#  9   interaction                                   5880 non-null   object
#  10  house_rules                                   5649 non-null   object
#  11  host_id                                       9148 non-null   int64
#  12  host_name                                     9147 non-null   object
#  13  host_since                                    9147 non-null   object
#  14  host_location                                 9128 non-null   object
#  15  host_about                                    5994 non-null   object
#  16  host_response_time                            5863 non-null   object
#  17  host_response_rate                            5863 non-null   object
#  18  host_acceptance_rate                          6757 non-null   object
#  19  host_is_superhost                             9147 non-null   object
#  20  host_neighbourhood                            8282 non-null   object
#  21  host_listings_count                           9147 non-null   float64
#  22  host_total_listings_count                     9147 non-null   float64
#  23  street                                        9148 non-null   object
#  24  neighbourhood                                 9148 non-null   object
#  25  neighbourhood_cleansed                        9148 non-null   object
#  26  city                                          9146 non-null   object
#  27  state                                         9141 non-null   object
#  28  zipcode                                       9078 non-null   object
#  29  market                                        9128 non-null   object
#  30  smart_location                                9148 non-null   object
#  31  country_code                                  9148 non-null   object
#  32  country                                       9148 non-null   object
#  33  latitude                                      9148 non-null   float64
#  34  longitude                                     9148 non-null   float64
#  35  is_location_exact                             9148 non-null   object
#  36  property_type                                 9148 non-null   object
#  37  room_type                                     9148 non-null   object
#  38  accommodates                                  9148 non-null   int64
#  39  bathrooms                                     9139 non-null   float64
#  40  bedrooms                                      9140 non-null   float64
#  41  beds                                          9113 non-null   float64
#  42  amenities                                     9148 non-null   object
#  43  price                                         9148 non-null   object
#  44  weekly_price                                  877 non-null    object
#  45  monthly_price                                 758 non-null    object
#  46  security_deposit                              6130 non-null   object
#  47  cleaning_fee                                  7396 non-null   object
#  48  extra_people                                  9148 non-null   object
#  49  minimum_nights                                9148 non-null   int64
#  50  maximum_nights                                9148 non-null   int64
#  51  availability_90                               9148 non-null   int64
#  52  availability_365                              9148 non-null   int64
#  53  number_of_reviews                             9148 non-null   int64
#  54  number_of_reviews_ltm                         9148 non-null   int64
#  55  first_review                                  6988 non-null   object
#  56  last_review                                   6988 non-null   object
#  57  review_scores_rating                          6879 non-null   float64
#  58  review_scores_accuracy                        6874 non-null   float64
#  59  review_scores_cleanliness                     6874 non-null   float64
#  60  review_scores_checkin                         6869 non-null   float64
#  61  review_scores_communication                   6874 non-null   float64
#  62  review_scores_location                        6870 non-null   float64
#  63  review_scores_value                           6867 non-null   float64
#  64  instant_bookable                              9148 non-null   object
#  65  is_business_travel_ready                      9148 non-null   object
#  66  require_guest_profile_picture                 9148 non-null   object
#  67  require_guest_phone_verification              9148 non-null   object
#  68  calculated_host_listings_count                9148 non-null   int64
#  69  calculated_host_listings_count_entire_homes   9148 non-null   int64
#  70  calculated_host_listings_count_private_rooms  9148 non-null   int64
#  71  calculated_host_listings_count_shared_rooms   9148 non-null   int64
#  72  reviews_per_month                             6988 non-null   float64
# dtypes: float64(15), int64(13), object(45)
# memory usage: 5.1+ MB

# %%
#reset the overall index of the table
LTS_GZ.reset_index()
# Out:
#       index        id                                             name  \
# 0         0      3663              Classic Rowhouse: Porch+ART+Parking
# 1         1      3670               Beautiful Sun-Lit U Street 1BR/1BA
# 2         2      3686                                  Vita's Hideaway
# 3         3      3771                                     Mt. Pleasant
# 4         4      4002     2 Bedroom Private Condo Suite (Basement Apt)
# ...     ...       ...                                              ...
# 9143   9143  43505599      ★Cozy & Spacious 2BR House ★ Free Parking ★
# 9144   9144  43506374                 Escape from the City in a Studio
# 9145   9145  43517424                                H Street Corridor
# 9146   9146  43518786  Unique home for long stay. You know if you know
# 9147   9147  43520275             Beautiful English Basement apartment
#
#                                                 summary  \
# 0     Bright, charming, artful home on bus line lead...
# 1     Convenient location perfect for business trave...
# 2     IMPORTANT NOTES * Carefully read and be sure t...
# 3     Clean, convenient and welcoming home.  Bedroom...
# 4     This is a very large beautiful English BASEMEN...
# ...                                                 ...
# 9143  First booking on Airbnb? Use this link to get ...
# 9144  This is a beautiful studio in North East D.C.....
# 9145        Bedroom is available for one or two people.
# 9146  You’re not moving to just an apartment. We tru...
# 9147  Welcome to this beautiful and historic English...
#
#                                                   space  \
# 0     NOTE: We are offering our home for rent here o...
# 1     Sunny, bright private room. Includes a queen s...
# 2     IMPORTANT NOTES * Airbnb keeps accurate track ...
# 3     Spacious, clean, convenient and welcoming home...
# 4     This is a very large (1400 SQ feet) beautiful ...
# ...                                                 ...
# 9143  Space is comfortably appointed with: - 2 queen...
# 9144  This studio has everything you need- Parking, ...
# 9145  Please read house rules to help your stay go s...
# 9146  Welcome to a boutique building with only 28 re...
# 9147                                                NaN
#
#                                             description  \
# 0     Bright, charming, artful home on bus line lead...
# 1     Convenient location perfect for business trave...
# 2     IMPORTANT NOTES * Carefully read and be sure t...
# 3     Clean, convenient and welcoming home.  Bedroom...
# 4     This is a very large beautiful English BASEMEN...
# ...                                                 ...
# 9143  First booking on Airbnb? Use this link to get ...
# 9144  This is a beautiful studio in North East D.C.....
# 9145  Bedroom is available for one or two people. Pl...
# 9146  You’re not moving to just an apartment. We tru...
# 9147  Welcome to this beautiful and historic English...
#
#                                   neighborhood_overview  \
# 0     The neighborhood: We are in the North Petworth...
# 1     We are nicely situated on a quiet residential ...
# 2     We love that our neighborhood is up and coming...
# 3                                                   NaN
# 4                    This is a very quite neighborhood.
# ...                                                 ...
# 9143  Cozy and Lovely 2 bedroom house located in Bro...
# 9144  Brentwood is the only industrial-zoned area in...
# 9145  Great area around the corner from the H Street...
# 9146  This is the heart of the lifestyle districts o...
# 9147                                                NaN
#
#                                                   notes  \
# 0                                                   NaN
# 1     There is one small dog living with us. He is h...
# 2     We love love love meeting people from around t...
# 3                                                   NaN
# 4     This is a below ground unit.  If you do not wa...
# ...                                                 ...
# 9143                                                NaN
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
#
#                                                 transit  \
# 0     Transportation: Free off-street parking behind...
# 1              Super convenient  public transportation.
# 2     We love that it only takes about 10 minutes to...
# 3                                                   NaN
# 4     Yes! Public transportation is very close to th...
# ...                                                 ...
# 9143  This lovely unit is a 10-20 minute walk to the...
# 9144  The nearest metro is about a 20-minute walk. I...
# 9145                             Walkable neighborhood.
# 9146  The apartment is in walking distance to two of...
# 9147                                                NaN
#
#                                                  access  \
# 0                                          Entire House
# 1                Private bedroom and en-suite bathroom.
# 2                                                   NaN
# 3     Guests access includes kitchen, dining room, l...
# 4     Right side basement/lower level.  Guest will h...
# ...                                                 ...
# 9143          Your reservation is for the entire house.
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
#
#                                             interaction  \
# 0     We will not be present, but available by phone...
# 1                            We live in the residesnce.
# 2     We allow guests to dictate the level of intera...
# 3                                                   NaN
# 4           On an as needed basis.  Usually at check-in
# ...                                                 ...
# 9143  We’re available as a resource to the guest thr...
# 9144  We live right above the space you will be enjo...
# 9145    I am a phone call away and respond immediately.
# 9146  Are you new to DC and need help upon arrival? ...
# 9147                                                NaN
#
#                                             house_rules    host_id  \
# 0                             No smoking inside No pets       4617
# 1                   No pets, parties or smoking please.       4630
# 2     *no illegal activity *no smoking *no pets *no ...       4645
# 3                                                   NaN       4795
# 4     Please note that the cleaning fee is only for ...       5143
# ...                                                 ...        ...
# 9143  ❤ Quiet hours begin at 10:00pm ❤ No parties or...   23714240
# 9144                                                NaN  347008743
# 9145                                                NaN   92781477
# 9146  Be respectful of our neighbors, our art and be...   33290388
# 9147                                                NaN  347219014
#
#             host_name  host_since  \
# 0     Shawn & Richard  2008-11-25
# 1              Sheila  2008-11-25
# 2                Vita  2008-11-26
# 3            Charlene  2008-12-03
# 4             Anthony  2008-12-13
# ...               ...         ...
# 9143             Nana  2014-11-13
# 9144           Sydney  2020-05-21
# 9145            Donna  2016-08-31
# 9146           Benoit  2015-05-13
# 9147           Karina  2020-05-23
#
#                                           host_location  \
# 0     Washington D.C., District of Columbia, United ...
# 1       Washington, District of Columbia, United States
# 2     Washington D.C., District of Columbia, United ...
# 3       Washington, District of Columbia, United States
# 4     Washington D.C., District of Columbia, United ...
# ...                                                 ...
# 9143    Washington, District of Columbia, United States
# 9144                 Snow Hill, Maryland, United States
# 9145                Woodbridge, Virginia, United States
# 9146             Locust Valley, New York, United States
# 9147                                                 US
#
#                                              host_about host_response_time  \
# 0     43 year old, former Peace Corps Volunteer who ...                NaN
# 1     I run a start-up food company with my partner ...                NaN
# 2     I am a literary scholar, teacher, poet, vegan ...       within a day
# 3     Retired Professional woman.  Work occasionally.                  NaN
# 4     I am a high school teacher and business owner....     within an hour
# ...                                                 ...                ...
# 9143  I'm a working professional loving life in the ...     within an hour
# 9144  Hi, We are Sydney and Camden and we moved to D...                NaN
# 9145  Hi, I’m Donna. I love to travel and want you t...     within an hour
# 9146  Benoit was born in France, has lived and trave...                NaN
# 9147                                                NaN                NaN
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 0                   NaN                  NaN                 f
# 1                   NaN                   0%                 f
# 2                  100%                 100%                 f
# 3                   NaN                  NaN                 f
# 4                  100%                 100%                 t
# ...                 ...                  ...               ...
# 9143               100%                  99%                 f
# 9144                NaN                 100%                 f
# 9145               100%                 100%                 f
# 9146                NaN                  NaN                 f
# 9147                NaN                  NaN                 f
#
#         host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0               Manor Park                  0.0                        0.0
# 1                      NaN                  1.0                        1.0
# 2                Anacostia                  2.0                        2.0
# 3             Mt. Pleasant                  1.0                        1.0
# 4            Michigan Park                  2.0                        2.0
# ...                    ...                  ...                        ...
# 9143          Capitol Hill                 16.0                       16.0
# 9144  Northeast Washington                  0.0                        0.0
# 9145   Mount Vernon Square                  5.0                        5.0
# 9146  Northwest Washington                  0.0                        0.0
# 9147  Northwest Washington                  0.0                        0.0
#
#                              street      neighbourhood  \
# 0     Washington, DC, United States         Manor Park
# 1     Washington, DC, United States  U Street Corridor
# 2     Washington, DC, United States          Anacostia
# 3     Washington, DC, United States     Mount Pleasant
# 4     Washington, DC, United States      Michigan Park
# ...                             ...                ...
# 9143  Washington, DC, United States          Woodridge
# 9144  Washington, DC, United States          Brentwood
# 9145  Washington, DC, United States           Trinidad
# 9146  Washington, DC, United States  U Street Corridor
# 9147  Washington, DC, United States       Logan Circle
#
#                                  neighbourhood_cleansed        city state  \
# 0                  Brightwood Park, Crestwood, Petworth  Washington    DC
# 1        Howard University, Le Droit Park, Cardozo/Shaw  Washington    DC
# 2                                    Historic Anacostia  Washington    DC
# 3     Columbia Heights, Mt. Pleasant, Pleasant Plain...  Washington    DC
# 4     North Michigan Park, Michigan Park, University...  Washington    DC
# ...                                                 ...         ...   ...
# 9143                   Woodridge, Fort Lincoln, Gateway  Washington    DC
# 9144                      Brookland, Brentwood, Langdon  Washington    DC
# 9145     Ivy City, Arboretum, Trinidad, Carver Langston  Washington    DC
# 9146         Dupont Circle, Connecticut Avenue/K Street  Washington    DC
# 9147         Dupont Circle, Connecticut Avenue/K Street  Washington    DC
#
#      zipcode market  smart_location country_code        country  latitude  \
# 0      20011   D.C.  Washington, DC           US  United States  38.95888
# 1      20009   D.C.  Washington, DC           US  United States  38.91842
# 2      20020   D.C.  Washington, DC           US  United States  38.86314
# 3      20009   D.C.  Washington, DC           US  United States  38.92760
# 4      20017   D.C.  Washington, DC           US  United States  38.94008
# ...      ...    ...             ...          ...            ...       ...
# 9143   20018   D.C.  Washington, DC           US  United States  38.93647
# 9144   20018   D.C.  Washington, DC           US  United States  38.91991
# 9145   20002   D.C.  Washington, DC           US  United States  38.90160
# 9146   20009   D.C.  Washington, DC           US  United States  38.91826
# 9147   20001   D.C.  Washington, DC           US  United States  38.90660
#
#       longitude is_location_exact property_type        room_type  \
# 0    -77.025540                 t     Townhouse  Entire home/apt
# 1    -77.027500                 f     Townhouse     Private room
# 2    -76.988360                 f         House     Private room
# 3    -77.039260                 t         Other     Private room
# 4    -76.989360                 t         House  Entire home/apt
# ...         ...               ...           ...              ...
# 9143 -76.976350                 t         House  Entire home/apt
# 9144 -76.980410                 t   Guest suite  Entire home/apt
# 9145 -76.987470                 t   Guest suite  Entire home/apt
# 9146 -77.037860                 t   Condominium  Entire home/apt
# 9147 -77.036631                 t         House     Private room
#
#       accommodates  bathrooms  bedrooms  beds  \
# 0                4        3.5       4.0   2.0
# 1                2        1.0       1.0   1.0
# 2                1        1.0       1.0   1.0
# 3                2        1.0       1.0   1.0
# 4                9        1.0       2.0   2.0
# ...            ...        ...       ...   ...
# 9143             6        2.5       2.0   2.0
# 9144             2        1.0       0.0   1.0
# 9145             1        1.5       1.0   1.0
# 9146             2        2.0       1.0   1.0
# 9147             4        1.0       2.0   0.0
#
#                                               amenities    price weekly_price  \
# 0     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $154.00          NaN
# 1     {Wifi,"Air conditioning","Pets live on this pr...   $75.00      $600.00
# 2     {Internet,Wifi,Kitchen,"Free street parking","...   $55.00      $430.00
# 3     {"Cable TV","Air conditioning",Heating,"Smoke ...   $88.00          NaN
# 4     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $120.00      $950.00
# ...                                                 ...      ...          ...
# 9143  {TV,Wifi,"Air conditioning",Kitchen,"Free park...  $150.00          NaN
# 9144  {TV,Wifi,"Air conditioning",Kitchen,"Free park...   $55.00          NaN
# 9145  {TV,Wifi,"Air conditioning",Kitchen,Heating,"F...   $50.00          NaN
# 9146  {Wifi,"Air conditioning",Kitchen,"Pets allowed...  $120.00          NaN
# 9147  {TV,Wifi,"Air conditioning",Kitchen,"Free park...   $80.00          NaN
#
#      monthly_price security_deposit cleaning_fee extra_people  minimum_nights  \
# 0              NaN            $0.00       $50.00        $0.00               3
# 1              NaN          $500.00       $25.00        $0.00               2
# 2          $975.00            $0.00        $0.00        $0.00               2
# 3              NaN              NaN          NaN        $0.00               1
# 4        $3,500.00          $200.00       $85.00       $20.00               2
# ...            ...              ...          ...          ...             ...
# 9143           NaN              NaN          NaN        $0.00               1
# 9144           NaN            $0.00       $10.00        $0.00               1
# 9145           NaN              NaN          NaN        $0.00               1
# 9146           NaN            $0.00      $200.00        $0.00              90
# 9147           NaN            $0.00        $0.00        $0.00               1
#
#       maximum_nights  availability_90  availability_365  number_of_reviews  \
# 0                 30               28               117                 41
# 1                 30                0                 0                 79
# 2                365               90               365                 72
# 3               1125                0                 0                  1
# 4                365               65                65                149
# ...              ...              ...               ...                ...
# 9143            1125               84               174                  0
# 9144            1125                4                55                  0
# 9145              14               15                15                  0
# 9146            1125               75               165                  0
# 9147              30               45                45                  0
#
#       number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                         0   2010-09-15  2018-05-21                  97.0
# 1                         0   2015-03-18  2018-07-25                  87.0
# 2                         2   2010-11-01  2020-04-01                  92.0
# 3                         0   2009-01-21  2009-01-21                   NaN
# 4                         0   2009-01-20  2018-11-13                  85.0
# ...                     ...          ...         ...                   ...
# 9143                      0          NaN         NaN                   NaN
# 9144                      0          NaN         NaN                   NaN
# 9145                      0          NaN         NaN                   NaN
# 9146                      0          NaN         NaN                   NaN
# 9147                      0          NaN         NaN                   NaN
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                       10.0                       10.0
# 1                        9.0                        9.0
# 2                        9.0                        9.0
# 3                        NaN                        NaN
# 4                        8.0                        8.0
# ...                      ...                        ...
# 9143                     NaN                        NaN
# 9144                     NaN                        NaN
# 9145                     NaN                        NaN
# 9146                     NaN                        NaN
# 9147                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 0                      10.0                         10.0
# 1                       9.0                          9.0
# 2                      10.0                         10.0
# 3                       NaN                          NaN
# 4                       9.0                          9.0
# ...                     ...                          ...
# 9143                    NaN                          NaN
# 9144                    NaN                          NaN
# 9145                    NaN                          NaN
# 9146                    NaN                          NaN
# 9147                    NaN                          NaN
#
#       review_scores_location  review_scores_value instant_bookable  \
# 0                        9.0                 10.0                f
# 1                       10.0                  9.0                f
# 2                        8.0                  9.0                f
# 3                        NaN                  NaN                f
# 4                        8.0                  8.0                t
# ...                      ...                  ...              ...
# 9143                     NaN                  NaN                t
# 9144                     NaN                  NaN                t
# 9145                     NaN                  NaN                t
# 9146                     NaN                  NaN                f
# 9147                     NaN                  NaN                t
#
#      is_business_travel_ready require_guest_profile_picture  \
# 0                           f                             f
# 1                           f                             f
# 2                           f                             f
# 3                           f                             f
# 4                           f                             f
# ...                       ...                           ...
# 9143                        f                             f
# 9144                        f                             f
# 9145                        f                             f
# 9146                        f                             f
# 9147                        f                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 0                                   f                               2
# 1                                   f                               1
# 2                                   f                               2
# 3                                   f                               1
# 4                                   t                               1
# ...                               ...                             ...
# 9143                                f                               9
# 9144                                f                               1
# 9145                                f                               4
# 9146                                f                               1
# 9147                                f                               1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               1
# ...                                           ...
# 9143                                            7
# 9144                                            1
# 9145                                            2
# 9146                                            1
# 9147                                            0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                1
# 2                                                2
# 3                                                1
# 4                                                0
# ...                                            ...
# 9143                                             2
# 9144                                             0
# 9145                                             2
# 9146                                             0
# 9147                                             1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.35
# 1                                               0               1.25
# 2                                               0               0.62
# 3                                               0               0.01
# 4                                               0               1.08
# ...                                           ...                ...
# 9143                                            0                NaN
# 9144                                            0                NaN
# 9145                                            0                NaN
# 9146                                            0                NaN
# 9147                                            0                NaN
#
# [9148 rows x 74 columns]

# %%
LTS_GZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9148 entries, 0 to 9147
# Data columns (total 73 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9148 non-null   int64
#  1   name                                          9146 non-null   object
#  2   summary                                       8923 non-null   object
#  3   space                                         7005 non-null   object
#  4   description                                   9036 non-null   object
#  5   neighborhood_overview                         6284 non-null   object
#  6   notes                                         4209 non-null   object
#  7   transit                                       6381 non-null   object
#  8   access                                        5428 non-null   object
#  9   interaction                                   5880 non-null   object
#  10  house_rules                                   5649 non-null   object
#  11  host_id                                       9148 non-null   int64
#  12  host_name                                     9147 non-null   object
#  13  host_since                                    9147 non-null   object
#  14  host_location                                 9128 non-null   object
#  15  host_about                                    5994 non-null   object
#  16  host_response_time                            5863 non-null   object
#  17  host_response_rate                            5863 non-null   object
#  18  host_acceptance_rate                          6757 non-null   object
#  19  host_is_superhost                             9147 non-null   object
#  20  host_neighbourhood                            8282 non-null   object
#  21  host_listings_count                           9147 non-null   float64
#  22  host_total_listings_count                     9147 non-null   float64
#  23  street                                        9148 non-null   object
#  24  neighbourhood                                 9148 non-null   object
#  25  neighbourhood_cleansed                        9148 non-null   object
#  26  city                                          9146 non-null   object
#  27  state                                         9141 non-null   object
#  28  zipcode                                       9078 non-null   object
#  29  market                                        9128 non-null   object
#  30  smart_location                                9148 non-null   object
#  31  country_code                                  9148 non-null   object
#  32  country                                       9148 non-null   object
#  33  latitude                                      9148 non-null   float64
#  34  longitude                                     9148 non-null   float64
#  35  is_location_exact                             9148 non-null   object
#  36  property_type                                 9148 non-null   object
#  37  room_type                                     9148 non-null   object
#  38  accommodates                                  9148 non-null   int64
#  39  bathrooms                                     9139 non-null   float64
#  40  bedrooms                                      9140 non-null   float64
#  41  beds                                          9113 non-null   float64
#  42  amenities                                     9148 non-null   object
#  43  price                                         9148 non-null   object
#  44  weekly_price                                  877 non-null    object
#  45  monthly_price                                 758 non-null    object
#  46  security_deposit                              6130 non-null   object
#  47  cleaning_fee                                  7396 non-null   object
#  48  extra_people                                  9148 non-null   object
#  49  minimum_nights                                9148 non-null   int64
#  50  maximum_nights                                9148 non-null   int64
#  51  availability_90                               9148 non-null   int64
#  52  availability_365                              9148 non-null   int64
#  53  number_of_reviews                             9148 non-null   int64
#  54  number_of_reviews_ltm                         9148 non-null   int64
#  55  first_review                                  6988 non-null   object
#  56  last_review                                   6988 non-null   object
#  57  review_scores_rating                          6879 non-null   float64
#  58  review_scores_accuracy                        6874 non-null   float64
#  59  review_scores_cleanliness                     6874 non-null   float64
#  60  review_scores_checkin                         6869 non-null   float64
#  61  review_scores_communication                   6874 non-null   float64
#  62  review_scores_location                        6870 non-null   float64
#  63  review_scores_value                           6867 non-null   float64
#  64  instant_bookable                              9148 non-null   object
#  65  is_business_travel_ready                      9148 non-null   object
#  66  require_guest_profile_picture                 9148 non-null   object
#  67  require_guest_phone_verification              9148 non-null   object
#  68  calculated_host_listings_count                9148 non-null   int64
#  69  calculated_host_listings_count_entire_homes   9148 non-null   int64
#  70  calculated_host_listings_count_private_rooms  9148 non-null   int64
#  71  calculated_host_listings_count_shared_rooms   9148 non-null   int64
#  72  reviews_per_month                             6988 non-null   float64
# dtypes: float64(15), int64(13), object(45)
# memory usage: 5.1+ MB

# %%
#####Change the strings to lower case 

#LTS_GZ = LTS_GZ.apply(lambda x: x.str.lower() if x.dtype == "object" else x) 
#LTS_GZ['summary','space', 'description','name', 'notes', 'transit', 'access'] = LTS_GZ['summary','space', 'description','name', 'notes', 'transit', 'access'].astype('str') 
#LTS_GZ['summary','space', 'description','name', 'notes', 'transit', 'access'] = LTS_GZ.str.lower(['summary','space', 'description','name', 'notes', 'transit', 'access'])
LTS_GZ.summary = LTS_GZ.summary.str.lower()
LTS_GZ.space = LTS_GZ.space.str.lower()
LTS_GZ.description = LTS_GZ.description.str.lower()
LTS_GZ.name = LTS_GZ.name.str.lower()
LTS_GZ.notes = LTS_GZ.notes.str.lower()
LTS_GZ.transit = LTS_GZ.transit.str.lower()
LTS_GZ.access= LTS_GZ.access.str.lower()
LTS_GZ.host_about= LTS_GZ.host_about.str.lower()

# %%
# #### First attempt at removing the "$" from money columns 

# LTS_GZ['price'] = LTS_GZ['price'].replace({'\$':''}, regex = True) 

# # comma in the columns prevents the above command from being used in conjunction with astype(float)

# LTS_GZ['price'] = LTS_GZ['price'].replace({',':''}, regex = True).astype(float)

# %%
####Code below changes all objects in LTS_GZ to floats
change_money = ['weekly_price', 'monthly_price', 'security_deposit']
# LTS_GZ[change_money] = LTS_GZ[change_money].replace({'\$':''}, regex = True)
# LTS_GZ[change_money] = LTS_GZ[change_money].replace({',':''}, regex = True).astype(float)

# %%
#### CHECK that money values are now floats
LTS_GZ.loc[:,['weekly_price','monthly_price','security_deposit','price']].dtypes
# Out:
# weekly_price        float64
# monthly_price       float64
# security_deposit    float64
# price               float64
# dtype: object

# %%
LTS_GZ
# Out:
#             id                                             name  \
# 0         3663              classic rowhouse: porch+art+parking
# 1         3670               beautiful sun-lit u street 1br/1ba
# 2         3686                                  vita's hideaway
# 3         3771                                     mt. pleasant
# 4         4002     2 bedroom private condo suite (basement apt)
# ...        ...                                              ...
# 9143  43505599      ★cozy & spacious 2br house ★ free parking ★
# 9144  43506374                 escape from the city in a studio
# 9145  43517424                                h street corridor
# 9146  43518786  unique home for long stay. you know if you know
# 9147  43520275             beautiful english basement apartment
#
#                                                 summary  \
# 0     bright, charming, artful home on bus line lead...
# 1     convenient location perfect for business trave...
# 2     important notes * carefully read and be sure t...
# 3     clean, convenient and welcoming home.  bedroom...
# 4     this is a very large beautiful english basemen...
# ...                                                 ...
# 9143  first booking on airbnb? use this link to get ...
# 9144  this is a beautiful studio in north east d.c.....
# 9145        bedroom is available for one or two people.
# 9146  you’re not moving to just an apartment. we tru...
# 9147  welcome to this beautiful and historic english...
#
#                                                   space  \
# 0     note: we are offering our home for rent here o...
# 1     sunny, bright private room. includes a queen s...
# 2     important notes * airbnb keeps accurate track ...
# 3     spacious, clean, convenient and welcoming home...
# 4     this is a very large (1400 sq feet) beautiful ...
# ...                                                 ...
# 9143  space is comfortably appointed with: - 2 queen...
# 9144  this studio has everything you need- parking, ...
# 9145  please read house rules to help your stay go s...
# 9146  welcome to a boutique building with only 28 re...
# 9147                                                NaN
#
#                                             description  \
# 0     bright, charming, artful home on bus line lead...
# 1     convenient location perfect for business trave...
# 2     important notes * carefully read and be sure t...
# 3     clean, convenient and welcoming home.  bedroom...
# 4     this is a very large beautiful english basemen...
# ...                                                 ...
# 9143  first booking on airbnb? use this link to get ...
# 9144  this is a beautiful studio in north east d.c.....
# 9145  bedroom is available for one or two people. pl...
# 9146  you’re not moving to just an apartment. we tru...
# 9147  welcome to this beautiful and historic english...
#
#                                   neighborhood_overview  \
# 0     The neighborhood: We are in the North Petworth...
# 1     We are nicely situated on a quiet residential ...
# 2     We love that our neighborhood is up and coming...
# 3                                                   NaN
# 4                    This is a very quite neighborhood.
# ...                                                 ...
# 9143  Cozy and Lovely 2 bedroom house located in Bro...
# 9144  Brentwood is the only industrial-zoned area in...
# 9145  Great area around the corner from the H Street...
# 9146  This is the heart of the lifestyle districts o...
# 9147                                                NaN
#
#                                                   notes  \
# 0                                                   NaN
# 1     there is one small dog living with us. he is h...
# 2     we love love love meeting people from around t...
# 3                                                   NaN
# 4     this is a below ground unit.  if you do not wa...
# ...                                                 ...
# 9143                                                NaN
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
#
#                                                 transit  \
# 0     transportation: free off-street parking behind...
# 1              super convenient  public transportation.
# 2     we love that it only takes about 10 minutes to...
# 3                                                   NaN
# 4     yes! public transportation is very close to th...
# ...                                                 ...
# 9143  this lovely unit is a 10-20 minute walk to the...
# 9144  the nearest metro is about a 20-minute walk. i...
# 9145                             walkable neighborhood.
# 9146  the apartment is in walking distance to two of...
# 9147                                                NaN
#
#                                                  access  \
# 0                                          entire house
# 1                private bedroom and en-suite bathroom.
# 2                                                   NaN
# 3     guests access includes kitchen, dining room, l...
# 4     right side basement/lower level.  guest will h...
# ...                                                 ...
# 9143          your reservation is for the entire house.
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
#
#                                             interaction  \
# 0     We will not be present, but available by phone...
# 1                            We live in the residesnce.
# 2     We allow guests to dictate the level of intera...
# 3                                                   NaN
# 4           On an as needed basis.  Usually at check-in
# ...                                                 ...
# 9143  We’re available as a resource to the guest thr...
# 9144  We live right above the space you will be enjo...
# 9145    I am a phone call away and respond immediately.
# 9146  Are you new to DC and need help upon arrival? ...
# 9147                                                NaN
#
#                                             house_rules    host_id  \
# 0                             No smoking inside No pets       4617
# 1                   No pets, parties or smoking please.       4630
# 2     *no illegal activity *no smoking *no pets *no ...       4645
# 3                                                   NaN       4795
# 4     Please note that the cleaning fee is only for ...       5143
# ...                                                 ...        ...
# 9143  ❤ Quiet hours begin at 10:00pm ❤ No parties or...   23714240
# 9144                                                NaN  347008743
# 9145                                                NaN   92781477
# 9146  Be respectful of our neighbors, our art and be...   33290388
# 9147                                                NaN  347219014
#
#             host_name  host_since  \
# 0     Shawn & Richard  2008-11-25
# 1              Sheila  2008-11-25
# 2                Vita  2008-11-26
# 3            Charlene  2008-12-03
# 4             Anthony  2008-12-13
# ...               ...         ...
# 9143             Nana  2014-11-13
# 9144           Sydney  2020-05-21
# 9145            Donna  2016-08-31
# 9146           Benoit  2015-05-13
# 9147           Karina  2020-05-23
#
#                                           host_location  \
# 0     Washington D.C., District of Columbia, United ...
# 1       Washington, District of Columbia, United States
# 2     Washington D.C., District of Columbia, United ...
# 3       Washington, District of Columbia, United States
# 4     Washington D.C., District of Columbia, United ...
# ...                                                 ...
# 9143    Washington, District of Columbia, United States
# 9144                 Snow Hill, Maryland, United States
# 9145                Woodbridge, Virginia, United States
# 9146             Locust Valley, New York, United States
# 9147                                                 US
#
#                                              host_about host_response_time  \
# 0     43 year old, former peace corps volunteer who ...                NaN
# 1     i run a start-up food company with my partner ...                NaN
# 2     i am a literary scholar, teacher, poet, vegan ...       within a day
# 3     retired professional woman.  work occasionally.                  NaN
# 4     i am a high school teacher and business owner....     within an hour
# ...                                                 ...                ...
# 9143  i'm a working professional loving life in the ...     within an hour
# 9144  hi, we are sydney and camden and we moved to d...                NaN
# 9145  hi, i’m donna. i love to travel and want you t...     within an hour
# 9146  benoit was born in france, has lived and trave...                NaN
# 9147                                                NaN                NaN
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 0                   NaN                  NaN                 f
# 1                   NaN                   0%                 f
# 2                  100%                 100%                 f
# 3                   NaN                  NaN                 f
# 4                  100%                 100%                 t
# ...                 ...                  ...               ...
# 9143               100%                  99%                 f
# 9144                NaN                 100%                 f
# 9145               100%                 100%                 f
# 9146                NaN                  NaN                 f
# 9147                NaN                  NaN                 f
#
#         host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0               Manor Park                  0.0                        0.0
# 1                      NaN                  1.0                        1.0
# 2                Anacostia                  2.0                        2.0
# 3             Mt. Pleasant                  1.0                        1.0
# 4            Michigan Park                  2.0                        2.0
# ...                    ...                  ...                        ...
# 9143          Capitol Hill                 16.0                       16.0
# 9144  Northeast Washington                  0.0                        0.0
# 9145   Mount Vernon Square                  5.0                        5.0
# 9146  Northwest Washington                  0.0                        0.0
# 9147  Northwest Washington                  0.0                        0.0
#
#                              street      neighbourhood  \
# 0     Washington, DC, United States         Manor Park
# 1     Washington, DC, United States  U Street Corridor
# 2     Washington, DC, United States          Anacostia
# 3     Washington, DC, United States     Mount Pleasant
# 4     Washington, DC, United States      Michigan Park
# ...                             ...                ...
# 9143  Washington, DC, United States          Woodridge
# 9144  Washington, DC, United States          Brentwood
# 9145  Washington, DC, United States           Trinidad
# 9146  Washington, DC, United States  U Street Corridor
# 9147  Washington, DC, United States       Logan Circle
#
#                                  neighbourhood_cleansed        city state  \
# 0                  Brightwood Park, Crestwood, Petworth  Washington    DC
# 1        Howard University, Le Droit Park, Cardozo/Shaw  Washington    DC
# 2                                    Historic Anacostia  Washington    DC
# 3     Columbia Heights, Mt. Pleasant, Pleasant Plain...  Washington    DC
# 4     North Michigan Park, Michigan Park, University...  Washington    DC
# ...                                                 ...         ...   ...
# 9143                   Woodridge, Fort Lincoln, Gateway  Washington    DC
# 9144                      Brookland, Brentwood, Langdon  Washington    DC
# 9145     Ivy City, Arboretum, Trinidad, Carver Langston  Washington    DC
# 9146         Dupont Circle, Connecticut Avenue/K Street  Washington    DC
# 9147         Dupont Circle, Connecticut Avenue/K Street  Washington    DC
#
#      zipcode market  smart_location country_code        country  latitude  \
# 0      20011   D.C.  Washington, DC           US  United States  38.95888
# 1      20009   D.C.  Washington, DC           US  United States  38.91842
# 2      20020   D.C.  Washington, DC           US  United States  38.86314
# 3      20009   D.C.  Washington, DC           US  United States  38.92760
# 4      20017   D.C.  Washington, DC           US  United States  38.94008
# ...      ...    ...             ...          ...            ...       ...
# 9143   20018   D.C.  Washington, DC           US  United States  38.93647
# 9144   20018   D.C.  Washington, DC           US  United States  38.91991
# 9145   20002   D.C.  Washington, DC           US  United States  38.90160
# 9146   20009   D.C.  Washington, DC           US  United States  38.91826
# 9147   20001   D.C.  Washington, DC           US  United States  38.90660
#
#       longitude is_location_exact property_type        room_type  \
# 0    -77.025540                 t     Townhouse  Entire home/apt
# 1    -77.027500                 f     Townhouse     Private room
# 2    -76.988360                 f         House     Private room
# 3    -77.039260                 t         Other     Private room
# 4    -76.989360                 t         House  Entire home/apt
# ...         ...               ...           ...              ...
# 9143 -76.976350                 t         House  Entire home/apt
# 9144 -76.980410                 t   Guest suite  Entire home/apt
# 9145 -76.987470                 t   Guest suite  Entire home/apt
# 9146 -77.037860                 t   Condominium  Entire home/apt
# 9147 -77.036631                 t         House     Private room
#
#       accommodates  bathrooms  bedrooms  beds  \
# 0                4        3.5       4.0   2.0
# 1                2        1.0       1.0   1.0
# 2                1        1.0       1.0   1.0
# 3                2        1.0       1.0   1.0
# 4                9        1.0       2.0   2.0
# ...            ...        ...       ...   ...
# 9143             6        2.5       2.0   2.0
# 9144             2        1.0       0.0   1.0
# 9145             1        1.5       1.0   1.0
# 9146             2        2.0       1.0   1.0
# 9147             4        1.0       2.0   0.0
#
#                                               amenities  price  weekly_price  \
# 0     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  154.0           NaN
# 1     {Wifi,"Air conditioning","Pets live on this pr...   75.0         600.0
# 2     {Internet,Wifi,Kitchen,"Free street parking","...   55.0         430.0
# 3     {"Cable TV","Air conditioning",Heating,"Smoke ...   88.0           NaN
# 4     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  120.0         950.0
# ...                                                 ...    ...           ...
# 9143  {TV,Wifi,"Air conditioning",Kitchen,"Free park...  150.0           NaN
# 9144  {TV,Wifi,"Air conditioning",Kitchen,"Free park...   55.0           NaN
# 9145  {TV,Wifi,"Air conditioning",Kitchen,Heating,"F...   50.0           NaN
# 9146  {Wifi,"Air conditioning",Kitchen,"Pets allowed...  120.0           NaN
# 9147  {TV,Wifi,"Air conditioning",Kitchen,"Free park...   80.0           NaN
#
#       monthly_price  security_deposit cleaning_fee extra_people  \
# 0               NaN               0.0       $50.00        $0.00
# 1               NaN             500.0       $25.00        $0.00
# 2             975.0               0.0        $0.00        $0.00
# 3               NaN               NaN          NaN        $0.00
# 4            3500.0             200.0       $85.00       $20.00
# ...             ...               ...          ...          ...
# 9143            NaN               NaN          NaN        $0.00
# 9144            NaN               0.0       $10.00        $0.00
# 9145            NaN               NaN          NaN        $0.00
# 9146            NaN               0.0      $200.00        $0.00
# 9147            NaN               0.0        $0.00        $0.00
#
#       minimum_nights  maximum_nights  availability_90  availability_365  \
# 0                  3              30               28               117
# 1                  2              30                0                 0
# 2                  2             365               90               365
# 3                  1            1125                0                 0
# 4                  2             365               65                65
# ...              ...             ...              ...               ...
# 9143               1            1125               84               174
# 9144               1            1125                4                55
# 9145               1              14               15                15
# 9146              90            1125               75               165
# 9147               1              30               45                45
#
#       number_of_reviews  number_of_reviews_ltm first_review last_review  \
# 0                    41                      0   2010-09-15  2018-05-21
# 1                    79                      0   2015-03-18  2018-07-25
# 2                    72                      2   2010-11-01  2020-04-01
# 3                     1                      0   2009-01-21  2009-01-21
# 4                   149                      0   2009-01-20  2018-11-13
# ...                 ...                    ...          ...         ...
# 9143                  0                      0          NaN         NaN
# 9144                  0                      0          NaN         NaN
# 9145                  0                      0          NaN         NaN
# 9146                  0                      0          NaN         NaN
# 9147                  0                      0          NaN         NaN
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     97.0                    10.0                       10.0
# 1                     87.0                     9.0                        9.0
# 2                     92.0                     9.0                        9.0
# 3                      NaN                     NaN                        NaN
# 4                     85.0                     8.0                        8.0
# ...                    ...                     ...                        ...
# 9143                   NaN                     NaN                        NaN
# 9144                   NaN                     NaN                        NaN
# 9145                   NaN                     NaN                        NaN
# 9146                   NaN                     NaN                        NaN
# 9147                   NaN                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 0                      10.0                         10.0
# 1                       9.0                          9.0
# 2                      10.0                         10.0
# 3                       NaN                          NaN
# 4                       9.0                          9.0
# ...                     ...                          ...
# 9143                    NaN                          NaN
# 9144                    NaN                          NaN
# 9145                    NaN                          NaN
# 9146                    NaN                          NaN
# 9147                    NaN                          NaN
#
#       review_scores_location  review_scores_value instant_bookable  \
# 0                        9.0                 10.0                f
# 1                       10.0                  9.0                f
# 2                        8.0                  9.0                f
# 3                        NaN                  NaN                f
# 4                        8.0                  8.0                t
# ...                      ...                  ...              ...
# 9143                     NaN                  NaN                t
# 9144                     NaN                  NaN                t
# 9145                     NaN                  NaN                t
# 9146                     NaN                  NaN                f
# 9147                     NaN                  NaN                t
#
#      is_business_travel_ready require_guest_profile_picture  \
# 0                           f                             f
# 1                           f                             f
# 2                           f                             f
# 3                           f                             f
# 4                           f                             f
# ...                       ...                           ...
# 9143                        f                             f
# 9144                        f                             f
# 9145                        f                             f
# 9146                        f                             f
# 9147                        f                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 0                                   f                               2
# 1                                   f                               1
# 2                                   f                               2
# 3                                   f                               1
# 4                                   t                               1
# ...                               ...                             ...
# 9143                                f                               9
# 9144                                f                               1
# 9145                                f                               4
# 9146                                f                               1
# 9147                                f                               1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               1
# ...                                           ...
# 9143                                            7
# 9144                                            1
# 9145                                            2
# 9146                                            1
# 9147                                            0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                1
# 2                                                2
# 3                                                1
# 4                                                0
# ...                                            ...
# 9143                                             2
# 9144                                             0
# 9145                                             2
# 9146                                             0
# 9147                                             1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.35
# 1                                               0               1.25
# 2                                               0               0.62
# 3                                               0               0.01
# 4                                               0               1.08
# ...                                           ...                ...
# 9143                                            0                NaN
# 9144                                            0                NaN
# 9145                                            0                NaN
# 9146                                            0                NaN
# 9147                                            0                NaN
#
# [9148 rows x 73 columns]

# %%
#CHANGE 'id' to 'listing_id'
#LTS_GZ.rename(columns={'id': 'listing_id'}, inplace=True)
#LTS.rename(columns={'id': 'listing_id'}, inplace=True)
