# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib.animation as animation

# %%
LTS = pd.read_csv('listings.csv', delimiter = ',', header = 0)
NBH = pd.read_csv('neighbourhoods.csv', delimiter = ',', header = 0)
REW = pd.read_csv('reviews.csv', delimiter = ',', header = 0)

# %%
CAL = pd.read_csv('calendar.csv.gz', delimiter = ',', header = 0, low_memory=False)
LTS_GZ = pd.read_csv('listings.csv.gz', delimiter = ',', header = 0, low_memory=False)
REW_GZ = pd.read_csv('reviews.csv.gz', delimiter = ',', header = 0, low_memory=False)

# %%
NBH_J= pd.read_json('neighbourhoods.geojson', lines=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', 50)

# %%
LTS.drop(columns=['neighbourhood_group','last_review'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-4ce8f6661d55> in <module>
# ----> 1 LTS.drop(columns=['neighbourhood_group','last_review'],inplace=True)
#       2 LTS
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['neighbourhood_group' 'last_review'] not found in axis"

# %%
LTS
# Out:
#             id                                             name    host_id  \
# 0         3663              Classic Rowhouse: Porch+ART+Parking       4617
# 1         3670               Beautiful Sun-Lit U Street 1BR/1BA       4630
# 2         3686                                  Vita's Hideaway       4645
# 3         3771                                     Mt. Pleasant       4795
# 4         4002     2 Bedroom Private Condo Suite (Basement Apt)       5143
# ...        ...                                              ...        ...
# 9143  43505599      ★Cozy & Spacious 2BR House ★ Free Parking ★   23714240
# 9144  43506374                 Escape from the City in a Studio  347008743
# 9145  43517424                                H Street Corridor   92781477
# 9146  43518786  Unique home for long stay. You know if you know   33290388
# 9147  43520275             Beautiful English Basement apartment  347219014
#
#             host_name                                      neighbourhood  \
# 0     Shawn & Richard               Brightwood Park, Crestwood, Petworth
# 1              Sheila     Howard University, Le Droit Park, Cardozo/Shaw
# 2                Vita                                 Historic Anacostia
# 3            Charlene  Columbia Heights, Mt. Pleasant, Pleasant Plain...
# 4             Anthony  North Michigan Park, Michigan Park, University...
# ...               ...                                                ...
# 9143             Nana                   Woodridge, Fort Lincoln, Gateway
# 9144           Sydney                      Brookland, Brentwood, Langdon
# 9145            Donna     Ivy City, Arboretum, Trinidad, Carver Langston
# 9146           Benoit         Dupont Circle, Connecticut Avenue/K Street
# 9147           Karina         Dupont Circle, Connecticut Avenue/K Street
#
#       latitude  longitude        room_type  price  minimum_nights  \
# 0     38.95888 -77.025540  Entire home/apt    154               3
# 1     38.91842 -77.027500     Private room     75               2
# 2     38.86314 -76.988360     Private room     55               2
# 3     38.92760 -77.039260     Private room     88               1
# 4     38.94008 -76.989360  Entire home/apt    120               2
# ...        ...        ...              ...    ...             ...
# 9143  38.93647 -76.976350  Entire home/apt    150               1
# 9144  38.91991 -76.980410  Entire home/apt     55               1
# 9145  38.90160 -76.987470  Entire home/apt     50               1
# 9146  38.91826 -77.037860  Entire home/apt    120              90
# 9147  38.90660 -77.036631     Private room     80               1
#
#       number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                    41               0.35                               2
# 1                    79               1.25                               1
# 2                    72               0.62                               2
# 3                     1               0.01                               1
# 4                   149               1.08                               1
# ...                 ...                ...                             ...
# 9143                  0                NaN                               9
# 9144                  0                NaN                               1
# 9145                  0                NaN                               4
# 9146                  0                NaN                               1
# 9147                  0                NaN                               1
#
#       availability_365
# 0                  117
# 1                    0
# 2                  365
# 3                    0
# 4                   65
# ...                ...
# 9143               174
# 9144                55
# 9145                15
# 9146               165
# 9147                45
#
# [9148 rows x 14 columns]

# %%
NBH.drop(columns=['neighbourhood_group'],inplace=True)

# %%
REW
# Out:
#         listing_id        date
# 0             3663  2010-09-15
# 1             3663  2010-10-16
# 2             3663  2010-10-24
# 3             3663  2010-11-03
# 4             3663  2011-03-11
# ...            ...         ...
# 355262    43336077  2020-05-10
# 355263    43336077  2020-05-19
# 355264    43415299  2020-05-15
# 355265    43415299  2020-05-18
# 355266    43416056  2020-05-18
#
# [355267 rows x 2 columns]

# %%
REW.date.max
# Out:
# '2020-05-23'

# %%
LTS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ec2619c5f088> in <module>
# ----> 1 LTS
#
# NameError: name 'LTS' is not defined
